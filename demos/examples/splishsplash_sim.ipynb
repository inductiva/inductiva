# %% [markdown]
# ### Low-level SPlisHSPlasH simulation
# Check out our [tutorials](https://github.com/inductiva/inductiva/tree/main/demos) if you want to learn more about simulators.

# %%
# Install the API dependencies and Inductiva modules
# !git config --global credential.helper 'cache'
# !pip install git+https://fabiocruz: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@github.com/inductiva/inductiva --no-cache

# %%
# Import Inductiva module
import inductiva

# %%
# Initialize a SPlisHSPlasH simulation with the input files
sph_sim = inductiva.fluids.simulators.SPlisHSPlasH(sim_dir="/home/begaiym/inductiva/sim_dir",
                                                   input_filename="splishsplash_input.json")

# %%
# Run the simulation on the server
output_path = sph_sim.simulate(output_dir="sim_outputs")
# Out:
# INFO:absl:Request submitted.
# INFO:absl:An executer has picked up the request.
# INFO:absl:The requested task is being executed remotely...
# INFO:absl:Task executed successfuly.

# %%
output_path
# Out:
# PosixPath('sim_outputs')

# %%
# Render simulation movie using Inductiva's visualization module
simulation = inductiva.fluids.SimulationOutput("sim_output")
simulation.render(movie_fps=14, color="blue")
# Out:
# INFO:absl:Creating movie frames...
# 100%|██████████| 61/61 [00:09<00:00,  6.50it/s]
# INFO:absl:Finished creating movie frames.
# INFO:absl:Creating movie 'sim_output/movie.mp4'.
#             <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4">
#             </video>
