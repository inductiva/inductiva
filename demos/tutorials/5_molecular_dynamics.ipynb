# %%
# %%capture
# !pip install inductiva

# %% [markdown]
# # Molecular Dynamics Simulation
#
# To show off that we are not

# %%
import inductiva

# Set the provided API token to be able to access our hardwarecon
inductiva.api_key = "396332389a8fe1f20663a08f57bbf9d697eb6d59631d96260a408fceaa62e9e8"

# %%
from google.colab import drive
drive.mount('/content/gdrive')

inductiva.working_dir = "/content/gdrive/MyDrive/API_Tutorials/Simulators/GROMACS"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
simulator = inductiva.molecules.simulators.GROMACS()

# %%
output = simulator.run(
  input_dir="gromacs_input",
  sim_config_filename="minim.mdp",
  protein_filename="1AKI_prep.gro",
  topology_filename="topol.top", 
  output_dir="molecules_out",
)
# Out:
# INFO:absl:Uploading input files...
# INFO:absl:Request submitted.
# INFO:absl:An executer has picked up the request.
# INFO:absl:The requested task is being executed remotely...
# INFO:absl:Task executed successfuly.
# INFO:absl:Downloading output...
# INFO:absl:Output downloaded.
# INFO:absl:Extracting output ZIP file to "/content/gdrive/MyDrive/API_Tutorials/Simulators/GROMACS/molecules_out"...
# INFO:absl:Output extracted.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
#Path for the plot data
plot_path = os.path.join(output, "em.xvg")

# %%
x, y = np.loadtxt(plot_path, comments=("@","#"),unpack=True)
plt.xlabel("Timesteps", size = 15)
plt.ylabel("Potential energy of the system (kJ/mol)", size = 15)
plt.title("Energy minimization", size = 20)
plt.plot(x,y)
