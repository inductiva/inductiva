# %% [markdown]
# # DualSPHysics simulation
#
#
# In this notebook you will run a DualSPHysics simulation.
#
# The configuration files for this simulation are provided in the folder `config_files` in the repository. If you did not download them, you can do it now.

# %%
# Install the API dependencies and Inductiva modules
# %%capture
# !pip install inductiva

# %%
# Import Inductiva module
import inductiva

# %% [markdown]
# ## Add here your API key
#
# The API key let's you run the simulators you want and iterate on the notebooks.
#
# To get one click [here](https://docs.google.com/forms/d/e/1FAIpQLSflytIIwzaBE_ZzoRloVm3uTo1OQCH6Cqhw3bhFVnC61s7Wmw/viewform).

# %%
# Add here your API key. 
inductiva.api_key = "YOUR_API_KEY"

# %% [markdown]
# ## Mount your google drive if running on Colab

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# Set the working path here. From now one, the paths you insert
# will be relative to this one.
inductiva.working_dir = "/content/gdrive/MyDrive/demos"

# %% [markdown]
# ## Setup the simulator and run a simulation

# %%
# Initialize a DualSPHysics simulation with the input files
dsph_sim = inductiva.simulators.DualSPHysics()

# %%
# Run the simulation on the server
output_path = dsph_sim.run(
    input_dir="config_files/dualsph",
    sim_config_filename="FlowCylinder_Re200.xml",
    output_dir="output/dualsph",
    n_cores=1)
# Out:
# INFO:absl:Request submitted.
# INFO:absl:An executer has picked up the request.
# INFO:absl:The requested task is being executed remotely...
# INFO:absl:Task executed successfuly.
